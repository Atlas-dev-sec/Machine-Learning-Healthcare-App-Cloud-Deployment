# %%
# data import
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
#data modelling
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score

# %%
data = pd.read_csv('data/parkinsons_data.csv')
data.head(5)
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3  phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4  phon_R01_S01_5      116.014       141.781       110.655         0.01284
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374  ...
# 1           0.00008   0.00465   0.00696     0.01394       0.06134  ...
# 2           0.00009   0.00544   0.00781     0.01633       0.05233  ...
# 3           0.00009   0.00502   0.00698     0.01505       0.05492  ...
# 4           0.00011   0.00655   0.00908     0.01966       0.06425  ...
#
#    Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# ...

# %%
print(len(data))
# Out:
# 195

# %%
# separate features and target
X = data.drop(columns=['name','status'], axis=1)
y = data['status']

print(X)
print(y)
# Out:
#      MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0        119.992       157.302        74.997         0.00784
# 1        122.400       148.650       113.819         0.00968
# 2        116.682       131.111       111.555         0.01050
# 3        116.676       137.871       111.366         0.00997
# 4        116.014       141.781       110.655         0.01284
# ..           ...           ...           ...             ...
# 190      174.188       230.978        94.261         0.00459
# 191      209.516       253.017        89.488         0.00564
# 192      174.688       240.005        74.287         0.01360
# 193      198.764       396.961        74.904         0.00740
# 194      214.289       260.277        77.973         0.00567
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# 0             0.00007   0.00370   0.00554     0.01109       0.04374
# 1             0.00008   0.00465   0.00696     0.01394       0.06134
# ...

# %%
xtrain,xtest, ytrain,ytest = train_test_split(X,y, test_size=0.2, random_state=2)

#standarize data
scaler = StandardScaler()

std_x_train = scaler.fit_transform(xtrain) 
std_x_test = scaler.fit_transform(xtest)

print(std_x_train)
print(std_x_test)
# Out:
# [[ 0.63239631 -0.02731081 -0.87985049 ... -0.97586547 -0.55160318
#    0.07769494]
#  [-1.05512719 -0.83337041 -0.9284778  ...  0.3981808  -0.61014073
#    0.39291782]
#  [ 0.02996187 -0.29531068 -1.12211107 ... -0.43937044 -0.62849605
#   -0.50948408]
#  ...
#  [-0.9096785  -0.6637302  -0.160638   ...  1.22001022 -0.47404629
#   -0.2159482 ]
#  [-0.35977689  0.19731822 -0.79063679 ... -0.17896029 -0.47272835
#    0.28181221]
#  [ 1.01957066  0.19922317 -0.61914972 ... -0.716232    1.23632066
#   -0.05829386]]
# [[-1.27434768e+00 -7.92100902e-01 -6.42064804e-01 -3.70550081e-02
#    7.65593976e-01 -5.36663194e-02  2.70521702e-01 -5.17113412e-02
#   -1.73362776e-01 -1.84537779e-01 -2.46162360e-01 -9.53432617e-02
#    3.51764171e-02 -2.46253875e-01 -2.42578071e-01 -5.71526263e-01
#    1.17904437e+00  1.05108661e+00  5.45105104e-01  2.12053870e+00
#    2.20220746e-01  6.73407367e-01]
#  [-9.93036290e-01 -7.55457877e-01 -6.02839911e-01  2.21517439e+00
# ...

# %%
'''
MODEL TRAINING

SVM MODEL

'''
model = svm.SVC(kernel='linear')

#training model
model.fit(std_x_train, ytrain)
# Out:
# SVC(kernel='linear')

# %%
'''
Model EVAL Training data
Accuracy score
'''

x_train_pred = model.predict(std_x_train)
train_data_acc = accuracy_score(ytrain, x_train_pred)

print('Accuracy score of training data: ', train_data_acc)
# Out:
# Accuracy score of training data:  0.8846153846153846

# %%
'''
Model EVAL Test data
Accuracy score
'''
x_test_pred = model.predict(std_x_test)
test_data_acc = accuracy_score(ytest, x_test_pred)

print("Accuracy score of test data: ", test_data_acc)
# Out:
# Accuracy score of test data:  0.8461538461538461

# %%
'''
Making a predictive system
'''
input_data = (119.992, 157.302, 74.997, 0.00784, 7e-05,
        0.0037, 0.00554, 0.01109, 0.04374, 0.426, 0.02182, 0.0313,
        0.02971, 0.06545, 0.02211, 21.033, 0.414783, 0.815285,
        -4.813031, 0.266482, 2.301442, 0.284654)

#convert to numpy array
input_data_as_arr =np.asarray(input_data)

# reshape data
input_data_reshaped = input_data_as_arr.reshape(1, -1)

# standarize input data
std_data = scaler.transform(input_data_reshaped)
#print(std_data)

prediction = model.predict(std_data)
#print(prediction)


if prediction[0] == 0:
  print('The patient does not have Parkinsons Disease')
else:
  print('The patient has Parkinsons Disease')
# Out:
# The patient has Parkinsons Disease
